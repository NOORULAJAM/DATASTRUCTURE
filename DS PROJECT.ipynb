# %%
class1=["ALI","HAMZA","DANISH","AHMED","MEHMOOD","RAZA ALI"]
class2=["YASIR","KASHIF","NOMAN","HABIB","NAZIM","RAZA ALI"]
class3=["SALMAN","YOUSUF","QADIR","AHSAN","JUNAID","RAZA ALI"] 
class4=["SHAHID","HAZEEZ","SHAHZAD","AKRAM","AYYAN","RAZA ALI"] 
class5=["FARHAN","ZAHEER","IMRAN","ADNAN","SADIQ","RAZA ALI"]

while True:
    print("**** NOOR-EDUCATOR SCHOOLING SYSTEM **** \n") 
    print("**** SCHOOL FUNCTIONS **** \n")
    print("1. CLASS I \n2. CLASS II \n3. CLASS III \n4. CLASS VI \n5. CLASS V \n"); 
    print("FOR CHECK STUDENT IN CLASS SALECT ANY CLASS NUMBER") 
    print("__________________________________________________")


    user=int(input("ENTER NUMBER FOR SEE THE CLASS STUDENT: "))


    if user == int(1): 
        print("\n ** CLASS I STUDENTS ARE *")
        print("\n",class1)    
        print("NOTE: \n IF YOU WANT TO SOME ADDION IN CLASS")

        print("1.)ADMISSION \n2.)ADMISSION CANCEL \n3.)EXIT") 

        option=int(input("ENTER NUMBER TO PERFROM FUNCTION :"))

        if option == int(1):
            admit=input("ENTER STUDENT NAME= :") 
            update=admit 
            class1.append(update) 
            print(class1)
        if option == int(2): 
            admit=input("ENTER STUDENT NAME= :")
            update=admit
            class1.remove(update)
            print(class1)
            
        if option ==int(3):
            exit()
         
    elif user == int(2): 
        print("\n ** CLASS II STUDENTS ARE *") 
        print("\n",class2) 
        print("NOTE: \n IF YOU WANT TO SOME ADDION IN CLASS") 
        print("1.)ADMISSION \n2.)ADMISSION CANCEL \n3.)EXIT") 
        option=int(input("ENTER NUMBER TO PERFROM FUNCTION :"))
        if option == int(1): 
            admit=input("ENTER STUDENT NAME= :") 
            update=admit 
            class2.append(update)
            print(class2)
        if option == int(2): 
            admit=input("ENTER STUDENT NAME= :")
            update=admit
            class2.remove(update)
            print(class2)
        if option ==int(3):
            exit()    
            
    elif user == int(3): 
        print("\n ** CLASS III STUDENTS ARE *") 
        print("\n",class3) 
        print("NOTE: \n IF YOU WANT TO SOME ADDION IN CLASS") 
        print("1.)ADMISSION \n2.)ADMISSION CANCEL \n3.)EXIT")
        option=int(input("ENTER NUMBER TO PERFROM FUNCTION :")) 
        if option == int(1):
            admit=input("ENTER STUDENT NAME= :") 
            update=admit 
            class3.append(update) 
            print(class3)
        if option == int(2): 
            admit=input("ENTER STUDENT NAME= :") 
            update=admit 
            class3.remove(update) 
            print(class3)
        
        if option ==int(3):
            exit()
            
    elif user == int(4):
        print("\n ** CLASS VI STUDENTS ARE *")
        print("\n",class4) 
        print("NOTE: \n IF YOU WANT TO SOME ADDION IN CLASS") 
        print("1.)ADMISSION \n2.)ADMISSION CANCEL \n3.)EXIT")

        option=int(input("ENTER NUMBER TO PERFROM FUNCTION :"))
        if option == int(1): 
            admit=input("ENTER STUDENT NAME= :") 
            update=admit 
            class4.append(update)
            print(class4) 
        if option == int(2): 
            admit=input("ENTER STUDENT NAME= :") 
            update=admit 
            class4.remove(update)
            print(class4)
        if option ==int(3):
            exit()    
    elif user == int(5):
        print("\n ** CLASS V STUDENTS ARE *")
        print("\n",class5)
        print("NOTE: \n IF YOU WANT TO SOME ADDION IN CLASS")
        print("1.)ADMISSION \n2.)ADMISSION CANCEL \n3.)EXIT")
        option=int(input("ENTER NUMBER TO PERFROM FUNCTION :")) 
        if option == int(1):
            admit=input("ENTER STUDENT NAME= :")
            update=admit 
            class5.append(update)
            print(class5)
        if option == int(2):
            admit=input("ENTER STUDENT NAME= :") 
            update=admit 
            class5.remove(update) 
            print(class5)
        if option ==int(3):
            exit()
